# %% [markdown]
# **Training is finished. We now need to convert the model into an inference type to allow for object detection on the test set. Reminder that we will retrain the model from scratch once we have preprocessed the images.**

# %%
# :3

# %%
# !nvidia-smi

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/fizyr/keras-retinanet

# %%
# !pip install keras-retinanet

# %%
# %cd '/content/keras-retinanet'
# !pip install . --user
# Optional
# !pip install --user git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI

# %cd '/content/drive/My Drive/keras-retinanet-main'
# !pip install . --user
# Optional
# !pip install --user git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI

# %%
# %cd '/content/keras-retinanet'

# %%
# !echo 'export PATH=$PATH:/root/.local/bin' >> ~/.bashrc
# !source ~/.bashrc

# %%
# To shorten path in training cell
#%cd '/content/keras-retinanet/keras_retinanet/bin'
# !ls

# %%
# %cd '/content/keras-retinanet/keras_retinanet/bin'
# !ls
# Out:
# /content/keras-retinanet/keras_retinanet/bin
# convert_model.py  debug.py  evaluate.py  __init__.py  train.py

# %%
# !python '/content/drive/My Drive/keras-retinanet-main/setup.py' build_ext --inplace
# !python '/content/keras-retinanet/setup.py' build_ext --inplace

# %%
# !python '/content/drive/My Drive/keras-retinanet-main/keras_retinanet/bin/train.py' --backbone=mobilenet128_1.0 csv '/content/drive/My Drive/Pothole Detection.v6i.retinanet.zip (Unzipped Files)/train/_annotations.csv' '/content/drive/My Drive/Pothole Detection.v6i.retinanet.zip (Unzipped Files)/train/classes.csv'

# %%
# %cd '/content/keras-retinanet/keras_retinanet/bin/snapshots'
# !ls

# %%
# Copy trained model to drive to be safe
# !cp "/content/keras-retinanet/keras_retinanet/bin/snapshots/mobilenet128_1.0_csv_50.h5" "/content/drive/My Drive"

# %%
# %cd '/content/keras-retinanet'
# !pwd
# !ls

# %%
# !python 'keras_retinanet/bin/convert_model.py' '/content/drive/My Drive/Models/mobilenet128_1.0_csv_50.h5' '/content/drive/My Drive/Models'

# %%
# !pip uninstall tensorflow keras -y  # Uninstall the current versions
# !pip install tensorflow==2.3.0  # Install specific TensorFlow version
# !pip install keras==2.4.0  # Install specific Keras version

# %%
# %env PYTHONPATH =
# Out:
# env: PYTHONPATH=

# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py38_4.12.0-Linux-x86_64.sh
# !chmod +x Miniconda3-py38_4.12.0-Linux-x86_64.sh
# !./Miniconda3-py38_4.12.0-Linux-x86_64.sh -b -f -p /usr/local
# !yes | conda update conda

# %%
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages')

# %%
# !yes | conda create -n myenv python=3.7

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# pip install tensorflow==2.3.0

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate myenv
# python3 '/content/drive/My Drive/keras-retinanet-main/keras_retinanet/bin/convert_model.py' '/content/drive/My Drive/Models/mobilenet128_1.0_csv_50.h5' '/content/drive/My Drive/Models'
# Out:
# 2023-11-24 21:03:10.611894: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-11-24 21:03:10.611929: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Traceback (most recent call last):
#   File "/content/drive/My Drive/keras-retinanet-main/keras_retinanet/bin/convert_model.py", line 31, in <module>
#     from ..utils.config import read_config_file, parse_anchor_parameters, parse_pyramid_levels
#   File "/content/drive/My Drive/keras-retinanet-main/keras_retinanet/bin/../../keras_retinanet/utils/config.py", line 20, in <module>
#     from ..utils.anchors import AnchorParameters
# ...

# %%
# !conda activate myen
# !pip --version
# !python --version

# %%
# !virtualenv myenv

# %%
# !pwd
# !ls
# Out:
# /content/keras-retinanet
# build		 examples  keras_retinanet	     LICENSE	requirements.txt  setup.py   tests
# CONTRIBUTORS.md  images    keras_retinanet.egg-info  README.md	setup.cfg	  snapshots

# %%
# !source myenv/bin/activate
